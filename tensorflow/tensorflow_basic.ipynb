# %%
import numpy as np
import tensorflow as tf

# %%
w = tf.Variable(0, dtype=tf.float32)
optimizer = tf.keras.optimizers.Adam(0.1)


def train_step():
  with tf.GradientTape() as tape:
    cost = w ** 2 - 10 * w + 25

  trainable_variables = [w]
  grads = tape.gradient(cost, trainable_variables)
  optimizer.apply_gradients(zip(grads, trainable_variables))

print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.0>

# %%
for i in range(1000):
  train_step()
print(w)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=5.000000953674316>

# %%
import tf_keras.optimizers.legacy as legacy

w = tf.Variable(0, dtype=tf.float32)
x = np.array([1.0, -10.0, 25.0], dtype=np.float32)
optimizer = legacy.Adam(0.1)

def training(x, w, optimizer):

  def cost_fn():
    return x[0] * w ** 2 + x[1] * w + x[2]

  for i in range(10):
    optimizer.apply_gradients(cost_fn, [w])

  return w

w = training(x, w, optimizer)
print(w)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-273799090.py in <cell line: 0>()
#      15   return w
#      16
# ---> 17 w = training(x, w, optimizer)
#      18 print(w)
#
# /tmp/ipython-input-273799090.py in training(x, w, optimizer)
#      11
#      12   for i in range(10):
# ---> 13     optimizer.apply_gradients(cost_fn, [w])
#      14
#      15   return w
#
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/optimizers/legacy/optimizer_v2.py in apply_gradients(self, grads_and_vars, name, experimental_aggregate_gradients)
#     702           RuntimeError: If called in a cross-replica context.
#     703         """
# --> 704         grads_and_vars = optimizer_utils.filter_empty_gradients(grads_and_vars)
#     705         var_list = [v for (_, v) in grads_and_vars]
#     706
#
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/optimizers/utils.py in filter_empty_gradients(grads_and_vars)
#      60 def filter_empty_gradients(grads_and_vars):
#      61     """Filter out `(grad, var)` pairs that have a gradient equal to `None`."""
# ---> 62     grads_and_vars = tuple(grads_and_vars)
#      63     if not grads_and_vars:
#      64         return grads_and_vars
#
# TypeError: 'function' object is not iterable
